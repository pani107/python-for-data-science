# %%
import cv2

# %%
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
img = cv2.imread(r"C:\Users\ashut\OneDrive\Pictures\Screenshots\Screenshot 2026-02-08 211448.png")
img
# Out:
# array([[[ 95,  88,  71],
#         [ 95,  88,  71],
#         [ 96,  90,  71],
#         ...,
#         [ 53,  54,  71],
#         [ 49,  51,  68],
#         [ 54,  59,  75]],
#
#        [[ 95,  88,  71],
#         [ 95,  88,  71],
#         [ 95,  88,  69],
#         ...,
#         [ 61,  62,  77],
#         [ 58,  59,  74],
#         [ 61,  65,  80]],
#
#        [[ 95,  88,  72],
#         [ 95,  88,  72],
#         [ 94,  86,  69],
#         ...,
#         [ 57,  58,  69],
#         [ 54,  55,  66],
#         [ 52,  54,  66]],
#
#        ...,
#
#        [[243, 244, 243],
#         [246, 247, 246],
#         [246, 247, 246],
#         ...,
#         [250, 240, 239],
#         [245, 236, 233],
#         [243, 234, 231]],
#
#        [[243, 243, 243],
#         [246, 246, 246],
#         [247, 247, 246],
#         ...,
#         [251, 242, 239],
#         [245, 236, 233],
#         [243, 234, 229]],
#
#        [[245, 245, 245],
#         [247, 247, 247],
#         [248, 248, 248],
# ...

# %% [markdown]
# # convert to grayscale

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
gray
# Out:
# array([[ 84,  84,  85, ...,  59,  56,  63],
#        [ 84,  84,  83, ...,  66,  63,  69],
#        [ 84,  84,  82, ...,  61,  58,  57],
#        ...,
#        [244, 247, 247, ..., 241, 236, 234],
#        [243, 246, 247, ..., 242, 236, 234],
#        [245, 247, 248, ..., 245, 240, 234]], shape=(191, 136), dtype=uint8)

# %% [markdown]
# # detect the face

# %%
faces = face_cascade.detectMultiScale(gray,1.1,4)
faces
# Out:
# array([[250,  67, 225, 225]], dtype=int32)

# %%
for(x,y,w,h) in faces:
    ROI  = img[y:y+h, x:+w]
    blur = cv2.GaussianBlur(ROI,(75,75),0)
    img[y:y+h, x:x+w] = blur
    cv2.rectangle(img, (x,y),(x+w, y+h),(0,0,255),2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 for (x, y, w, h) in faces:
# ----> 2         ROI = img[y:y+h, x:x+w]
#       3         blur = cv2.GaussianBlur(ROI, (75, 75), 0)
#       4         img[y:y+h, x:x+w] = blur
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# # show original image

# %%
import cv2

# %% [markdown]
# # read the image

# %%
img = cv2.imread(r"C:\Users\ashut\OneDrive\Pictures\Screenshots\Screenshot 2026-02-08 211448.png")
img
# Out:
# array([[[ 95,  88,  71],
#         [ 95,  88,  71],
#         [ 96,  90,  71],
#         ...,
#         [ 53,  54,  71],
#         [ 49,  51,  68],
#         [ 54,  59,  75]],
#
#        [[ 95,  88,  71],
#         [ 95,  88,  71],
#         [ 95,  88,  69],
#         ...,
#         [ 61,  62,  77],
#         [ 58,  59,  74],
#         [ 61,  65,  80]],
#
#        [[ 95,  88,  72],
#         [ 95,  88,  72],
#         [ 94,  86,  69],
#         ...,
#         [ 57,  58,  69],
#         [ 54,  55,  66],
#         [ 52,  54,  66]],
#
#        ...,
#
#        [[243, 244, 243],
#         [246, 247, 246],
#         [246, 247, 246],
#         ...,
#         [250, 240, 239],
#         [245, 236, 233],
#         [243, 234, 231]],
#
#        [[243, 243, 243],
#         [246, 246, 246],
#         [247, 247, 246],
#         ...,
#         [251, 242, 239],
#         [245, 236, 233],
#         [243, 234, 229]],
#
#        [[245, 245, 245],
#         [247, 247, 247],
#         [248, 248, 248],
# ...

# %%
t_lower = 50
t_upper = 50

# %% [markdown]
# # apply the canny edge filter

# %%
edge = cv2.Canny(img, t_lower, t_upper)

# %% [markdown]
# # show original and edge image

# %%
cv2.imshow('original',img)
cv2.imshow('edge',edge)

# %% [markdown]
# # relese the window object

# %%
cv2.waitKey(0)
cv2.destroyAllWindows()

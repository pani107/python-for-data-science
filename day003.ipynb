# %%
import numpy as np
import pandas as pd 
import seaborn as sns

# %% [markdown]
# # Outlier Detection and Removal using the IQR Method

# %%
df = sns.load_dataset("titanic")

# %%
#df.describe(include="object") 
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
sns.boxplot(x = df["fare"])
# Out:
# <Axes: xlabel='fare'>

# %%
sns.boxenplot(x = df["fare"])
# Out:
# <Axes: xlabel='fare'>

# %%
df = df.select_dtypes("number")

# %%
iqr_results = {}

for col in df.columns:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - (1.5 * IQR)
    upper = Q3 + (1.5 * IQR)

    outliers = df[
        (df[col] < lower) |
        (df[col] > upper)
    ]

    iqr_results[col] = len(outliers)

print(iqr_results)
# Out:
# {'survived': 0, 'pclass': 0, 'age': 11, 'sibsp': 46, 'parch': 213, 'fare': 116}

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in df.select_dtypes(include=['int64', 'float64']).columns:
    plt.figure(figsize=(6,3))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
pd.DataFrame(
    iqr_results.items(),
    columns=["feature", "outlier_count"]
).sort_values(
    by="outlier_count",
    ascending=False
)
# Out:
#     feature  outlier_count
# 4     parch            213
# 5      fare            116
# 3     sibsp             46
# 2       age             11
# 0  survived              0
# 1    pclass              0

# %% [markdown]
# # Data visulizaion

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

# %%
a = np.array([1,2,3,4])
b = np.array([6,7,8,9])

# %%
plt.plot(a,b, )
plt.xlabel(" X axis")
plt.ylabel(" Y axis")
plt.title("regression plot")
# Out:
# Text(0.5, 1.0, 'regression plot')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s , c="g")

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

fig.savefig("test.png")
plt.show()

# %%
# First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# Create just a figure and only one subplot
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Simple plot')

# Create two subplots and unpack the output array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)

# Create four polar Axes and access them through the returned array
fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
axs[0, 0].plot(x, y)
axs[1, 1].scatter(x, y)

# Share a X axis with each column of subplots
plt.subplots(2, 2, sharex='col')
plt.grid()
# Share a Y axis with each row of subplots
plt.subplots(2, 2, sharey='row')

# Share both X and Y axes with all subplots
plt.subplots(2, 2, sharex='all', sharey='all')

# Note that this is the same as
plt.subplots(2, 2, sharex=True, sharey=True)

# Create figure number 10 with a single subplot
# and clears it if it already exists.
fig, ax = plt.subplots(num=10, clear=True)

# %% [markdown]
# # bar plot

# %%
height = [4,2,3,4,6]
bar = ["A","B","C","D","E"]
x_pos = np.arange(len(bar))

plt.bar(x_pos,height,color=("green","black","orange","yellow","pink"))

plt.xticks(x_pos ,bar)
plt.yticks(height)

plt.show()

# %% [markdown]
# # Histogram

# %%
a1 = np.random.normal(100,10,1000)

# %%
plt.hist(a1)
# Out:
# (array([ 14.,  25.,  92., 187., 240., 216., 155.,  50.,  14.,   7.]),
#  array([ 70.31816512,  76.51233406,  82.70650301,  88.90067195,
#          95.09484089, 101.28900983, 107.48317878, 113.67734772,
#         119.87151666, 126.0656856 , 132.25985455]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
sns.histplot(a1)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.kdeplot(a1)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.histplot(a1,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.distplot(a1)
# Out:
# <Axes: ylabel='Density'>

# %%
df = sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df1 = df.select_dtypes = "number"

# %% [markdown]
# corr = df.corr(numeric_only=True)
#
# print(corr)
# sns.heatmap(corr , annot=True ,linewidths=1, vmax=1, linecolor="skyblue" )

# %% [markdown]
# # Machine Learning

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ashut\OneDrive\Desktop\heart_1.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB
# None

# %%
# How many patients have heart disease (target=1) vs do not have heart disease (target=0).

import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='target', data=df)
plt.title("Distribution of Heart Disease")
plt.show()

print(df['target'].value_counts())
print(df['target'].value_counts(normalize=True) * 100)
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64
# target
# 1    51.317073
# 0    48.682927
# Name: proportion, dtype: float64

# %%
# Are older people more likely to have heart disease.
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

sns.boxplot(
    x='target',
    y='age',
    data=df
)

plt.title("Age vs Heart Disease")
plt.xlabel("Heart Disease (0 = No, 1 = Yes)")
plt.ylabel("Age")
plt.show()

df.groupby('target')['age'].agg(['mean', 'median', 'min', 'max'])

plt.figure(figsize=(8,5))

sns.histplot(
    data=df,
    x='age',
    hue='target',
    kde=True,
    bins=20
)

plt.title("Age Distribution by Heart Disease")
plt.show()

# %%
# Which gender has a higher heart disease rate.
# blue bar indicate no heart disease and orange bar indicate heart disease person
# Females show a higher heart disease rate (72.44%) compared to males (42.08%).
# The dataset contains more males (713) than females (312).
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

sns.countplot(
    x='sex',
    hue='target',
    data=df
)

plt.title("Gender vs Heart Disease")
plt.xlabel("Sex (0 = Female, 1 = Male)")
plt.ylabel("Count")
plt.show()

gender_target = pd.crosstab(
    df['sex'],
    df['target'],
    normalize='index'
) * 100

print(gender_target)

df['sex'].value_counts()
# Out:
# target          0          1
# sex
# 0       27.564103  72.435897
# 1       57.924264  42.075736
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %%
# target:
# 0 = No Heart Disease
# 1 = Heart Disease Present
# cp:
# 0 = Typical Angina
# 1 = Atypical Angina
# 2 = Non-anginal Pain
# 3 = Asymptomatic
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

sns.countplot(
    x='cp',
    hue='target',
    data=df
)

plt.title("Chest Pain Type vs Heart Disease")
plt.xlabel("Chest Pain Type")
plt.ylabel("Count")
plt.show()

cp_target = pd.crosstab(
    df['cp'],
    df['target'],
    normalize='index'
) * 100

print(cp_target)

pd.crosstab(df['cp'], df['target'])
# Out:
# target          0          1
# cp
# 0       75.452716  24.547284
# 1       19.760479  80.239521
# 2       22.887324  77.112676
# 3       33.766234  66.233766
# target    0    1
# cp
# 0       375  122
# 1        33  134
# 2        65  219
# 3        26   51

# %%
# Do patients with heart disease have higher cholesterol
sns.boxplot(x='target', y='chol', data=df)
plt.show()

# %%
#Step 1: Verify the Finding
#First calculate the heart disease percentage by gender.
gender_target = pd.crosstab(
    df['sex'],
    df['target'],
    normalize='index'
) * 100

print(gender_target)
# Out:
# target          0          1
# sex
# 0       27.564103  72.435897
# 1       57.924264  42.075736

# %%
#Hypothesis 1: Are Females Older?
df.groupby('sex')['age'].describe()
# Out:
#      count       mean       std   min   25%   50%   75%   max
# sex
# 0    312.0  55.849359  9.368127  34.0  50.0  57.0  63.0  76.0
# 1    713.0  53.814867  8.875668  29.0  47.0  55.0  60.0  77.0

# %%
# If age does not completely explain the difference, do females have worse cholesterol levels?
df.groupby('sex')['chol'].describe()
# Out:
#      count        mean        std    min    25%    50%    75%    max
# sex
# 0    312.0  261.455128  64.466781  141.0  215.0  254.0  302.0  564.0
# 1    713.0  239.237027  43.155535  126.0  208.0  234.0  269.0  353.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

sns.boxplot(
    x='sex',
    y='chol',
    data=df
)

plt.xticks([0,1], ['Female','Male'])
plt.title("Cholesterol Distribution by Gender")
plt.xlabel("Gender")
plt.ylabel("Cholesterol")

plt.show()

# %%
df.groupby('sex')['chol'].mean()
# Out:
# sex
# 0    261.455128
# 1    239.237027
# Name: chol, dtype: float64

# %%
# Hypothesis 3: Do Females Have Higher Blood Pressure
df.groupby('sex')['trestbps'].describe()
sns.boxplot(x='sex', y='trestbps', data=df)

plt.xticks([0,1], ['Female','Male'])
plt.title("Resting Blood Pressure by Gender")
plt.show()

# %%
# Hypothesis 4: Compare Heart Disease Rates by Age and Gender
sns.boxplot(
    x='sex',
    y='age',
    hue='target',
    data=df
)

plt.xticks([0,1], ['Female','Male'])
plt.show()
pd.crosstab(
    df['sex'],
    df['target']
)
# Out:
# target    0    1
# sex
# 0        86  226
# 1       413  300

# %%
df['age_group'] = pd.cut(
    df['age'],
    bins=[0,40,50,60,70,100],
    labels=['<40','40-50','50-60','60-70','70+']
)

result = pd.crosstab(
    [df['age_group'], df['sex']],
    df['target'],
    normalize='index'
) * 100

print(result)

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

sns.barplot(
    data=df,
    x='age_group',
    y='target',
    hue='sex'
)

plt.title("Heart Disease Rate by Age Group and Gender")
plt.ylabel("Heart Disease Rate")
plt.show()

df.groupby(['sex','target'])['chol'].agg(
    ['count','mean','median','max']
)
# Out:
# target                  0           1
# age_group sex
# <40       0      0.000000  100.000000
#           1     45.098039   54.901961
# 40-50     0      5.882353   94.117647
#           1     43.016760   56.983240
# 50-60     0     33.628319   66.371681
#           1     60.307692   39.692308
# 60-70     0     45.360825   54.639175
#           1     73.548387   26.451613
# 70+       0      0.000000  100.000000
#           1    100.000000    0.000000
#             count        mean  median  max
# sex target
# 0   0          86  276.732558   268.0  409
#     1         226  255.641593   248.0  564
# 1   0         413  245.995157   246.0  353
#     1         300  229.933333   227.0  325

# %%
df.groupby(['sex','target'])['chol'].agg(
    ['count','mean','median','min','max']
)

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

sns.boxplot(
    x='sex',
    y='chol',
    hue='target',
    data=df
)

plt.xticks([0,1], ['Female','Male'])
plt.title("Cholesterol by Gender and Heart Disease")

plt.show()

# %% [markdown]
#  # model Building

# %%
from sklearn.model_selection import train_test_split # import sklearn library

X = df.drop("age_group", axis=1)  # input 
y = df["target"]               #output

x_train, x_test, y_train, y_test = train_test_split(      # train the data on the basis of train test split        
    X, y,
    test_size=0.3,
    random_state=42
)

# %%
df.shape
# Out:
# (1025, 15)

# %%
x_train.shape
# Out:
# (717, 14)

# %%
x_test.shape
# Out:
# (308, 14)

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()

# %%
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = log.predict(x_train)

# %%
y_pred.shape
# Out:
# (717,)

# %%
y_test.shape
# Out:
# (308,)

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(y_pred,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 report = classification_report(y_pred,y_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
# ...
